# %% [markdown]
# # GRÁFICAS PARA ESTADÍSTICA DESCRIPTIVA

# %%
import matplotlib.pyplot as plt
print("Setup terminado")
# Out:
# Setup terminado

# %% [markdown]
# Alumno: Estrada Barragan Añlvaro Sandro
# Matricula: 240110052
# [Índice](index.ipynb)

# %%
datos = [5, 12, 23, 25, 20, 15]
separaciones = [0, 0, 0, 0.1, 0, 0]
plt.pie(datos,
        explode = separaciones, 
        labels = ["Coca", "Toronja", "Sprite", "Manzanita", "Punch", "Jarrito"],
       colors = ["#740505", "#740560", "#B227C6", "#9363D3", "#6372D3", "#63B1D3" ],
       autopct = "% 0.1f %%", 
       pctdistance = 0.8,
       counterclock = False,
       startangle = 90)
plt.show()
